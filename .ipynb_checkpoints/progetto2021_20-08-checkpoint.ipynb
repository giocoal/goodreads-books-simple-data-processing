# %%
import pandas as pd
import re
#from IPython.display import display
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 20)

# %% [markdown]
# ### Load the datasets

# %%
books = pd.read_csv("https://github.com/gdv/foundationsCS/raw/master/progetti/2021/Books.csv.gz", compression = 'gzip', 
                    sep = ';', encoding = 'latin-1', low_memory=False)
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
ratings = pd.read_csv("https://github.com/gdv/foundationsCS/raw/master/progetti/2021/Book-Ratings.csv.gz", compression = 'gzip',
                      sep = ';', encoding = 'latin-1', low_memory=False)
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
users = pd.read_csv("https://github.com/gdv/foundationsCS/raw/master/progetti/2021/Users.csv.gz", compression = 'gzip', 
                    sep = ';', encoding = 'latin-1', low_memory=False)
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
goodbooks = pd.read_csv("https://github.com/gdv/foundationsCS/raw/master/progetti/2021/goodbooks.csv.gz", compression = 'gzip', 
                        encoding = 'latin-1', low_memory=False)
goodbooks.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                       authors  original_publication_year  \
# 0  9.780439e+12               Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPrÃ©                     1997.0
# 2  9.780316e+12               Stephenie Meyer                     2005.0
# 3  9.780061e+12                    Harper Lee                     1960.0
# 4  9.780743e+12           F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %%
goodbooks_ratings = pd.read_csv("https://github.com/gdv/foundationsCS/raw/master/progetti/2021/goodbooks-ratings.csv.gz", 
                                compression = 'gzip', encoding = 'latin-1', low_memory=False)
goodbooks_ratings.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %% [markdown]
# ### 1) Normalize the location field of Users dataset, splitting into city, region, country

# %%
users[['City', 'Region', 'Country']] = users['Location'].str.split(',', expand = True, n=2)
users.drop('Location', axis = 1, inplace = True)
users.head()
# Out:
#    User-ID   Age         City            Region          Country
# 0        1   NaN          nyc          new york              usa
# 1        2  18.0     stockton        california              usa
# 2        3   NaN       moscow   yukon territory           russia
# 3        4  17.0        porto          v.n.gaia         portugal
# 4        5   NaN  farnborough             hants   united kingdom

# %% [markdown]
# ### 2) For each book in the Books dataset, compute its average rating.

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
books_w_ratings = pd.merge(books, ratings, on='ISBN', how='left')
books_w_ratings.head()
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
# 2  0002005018         Clara Callan  Richard Bruce Wright                2001
# 3  0002005018         Clara Callan  Richard Bruce Wright                2001
# 4  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L  User-ID  Book-Rating
# 0  http://images.amazon.com/images/P/0195153448.0...      2.0          0.0
# 1  http://images.amazon.com/images/P/0002005018.0...      8.0          5.0
# 2  http://images.amazon.com/images/P/0002005018.0...  11400.0          0.0
# 3  http://images.amazon.com/images/P/0002005018.0...  11676.0          8.0
# 4  http://images.amazon.com/images/P/0002005018.0...  41385.0          0.0

# %%
books_avg = books_w_ratings.groupby(['ISBN', 'Book-Title'], as_index=False)['Book-Rating'].mean()
books_avg.head(15)
# Out:
#           ISBN                                         Book-Title  Book-Rating
# 0   0000913154  The Way Things Work: An Illustrated Encycloped...          8.0
# 1   0001010565                                    Mog's Christmas          0.0
# 2   0001046438                                               Liar          9.0
# 3   0001046713                       Twopence to Cross the Mersey          0.0
# 4   000104687X  T.S. Eliot Reading \The Wasteland\" and Other ...          6.0
# 5   0001046934                      The Prime of Miss Jean Brodie          0.0
# 6   0001047213                                   The Fighting Man          9.0
# 7   0001047647                                 First Among Equals          0.0
# 8   0001047663                                   Matter Of Honour          0.0
# 9   0001047868                                          Kidnapped          0.0
# 10  0001047973                                    Brave New World          9.0
# 11  000104799X                                        Monk's-hood          7.5
# 12  0001048082                                    Made in America          8.0
# 13  0001048473                              Nothing Can Be Better          0.0
# 14  0001049879                             Daughters of the Storm          0.0

# %% [markdown]
# ### 3) For each book in the GoodBooks dataset, compute its average rating.

# %%
goodbooks.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                       authors  original_publication_year  \
# 0  9.780439e+12               Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPrÃ©                     1997.0
# 2  9.780316e+12               Stephenie Meyer                     2005.0
# 3  9.780061e+12                    Harper Lee                     1960.0
# 4  9.780743e+12           F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %%
goodbooks[['book_id', 'original_title', 'average_rating']]
# Out:
#     book_id                            original_title  average_rating
# 0         1                          The Hunger Games            4.34
# 1         2  Harry Potter and the Philosopher's Stone            4.44
# 2         3                                  Twilight            3.57
# 3         4                     To Kill a Mockingbird            4.25
# 4         5                          The Great Gatsby            3.89
# ..      ...                                       ...             ...
# 94       95                The Picture of Dorian Gray            4.06
# 95       96                        Fifty Shades Freed            3.88
# 96       97                                   Dracula            3.98
# 97       98               Flickan som lekte med elden            4.22
# 98       99                       Fifty Shades Darker            3.87
#
# [99 rows x 3 columns]

# %% [markdown]
# ### 4) Merge together all rows sharing the same book title, author and publisher. We will call the resulting datset merged books. The books that have not been merged together will not appear in merged books.

# %%
merged = books.groupby(['Book-Title', 'Book-Author', 'Publisher'], as_index=False).size()
merged.head()
# Out:
#                                           Book-Title       Book-Author  \
# 0   A Light in the Storm: The Civil War Diary of ...       Karen Hesse
# 1                              Always Have Popsicles    Rebecca Harvin
# 2               Apple Magic (The Collector's series)  Martina Boudreau
# 3   Ask Lily (Young Women of Faith: Lily Series, ...      Nancy N. Rue
# 4   Beyond IBM: Leadership Marketing and Finance ...        Lou Mobley
#
#                      Publisher  size
# 0  Hyperion Books for Children     1
# 1            Rebecca L. Harvin     1
# 2           Amer Cooking Guild     1
# 3                   Zonderkidz     1
# 4       Teleonet, Incorporated     1

# %%
merged_books = merged[merged['size']>1]
merged_books.head()
# Out:
#                                             Book-Title  \
# 41                           !%@ (A Nutshell handbook)
# 59   'A Hell of a Place to Lose a Cow': An American...
# 255  10,000 dreams interpreted: A dictionary of dreams
# 465                                   101 Famous Poems
# 713                 15 Houseplants Even You Can't Kill
#
#                  Book-Author                       Publisher  size
# 41             Donnalyn Frey                        O'Reilly     2
# 59               Tim Brookes             National Geographic     2
# 255  Gustavus Hindman Miller       Barnes &amp; Nobles Books     2
# 465              Roy J. Cook  McGraw-Hill/Contemporary Books     3
# 713                Joe Elder               Berkley Pub Group     2

# %%
len(merged_books)
# Out:
# 4725

# %% [markdown]
# ### 5) For each book in merged books compute its average rating.

# %%
merged_books_w_avg = pd.merge(merged_books, books_avg, on="Book-Title")
merged_books_w_avg.head()
# Out:
#                                           Book-Title              Book-Author  \
# 0                          !%@ (A Nutshell handbook)            Donnalyn Frey
# 1                          !%@ (A Nutshell handbook)            Donnalyn Frey
# 2  'A Hell of a Place to Lose a Cow': An American...              Tim Brookes
# 3  'A Hell of a Place to Lose a Cow': An American...              Tim Brookes
# 4  10,000 dreams interpreted: A dictionary of dreams  Gustavus Hindman Miller
#
#                    Publisher  size        ISBN  Book-Rating
# 0                   O'Reilly     2  1565920317         6.00
# 1                   O'Reilly     2  1565920465         0.00
# 2        National Geographic     2  0792276833         0.00
# 3        National Geographic     2  0792277295         3.40
# 4  Barnes &amp; Nobles Books     2  1566196256         7.25

# %%
merged_books_w_avg.groupby(['Book-Title', 'Book-Author', 'Publisher'], as_index=False)['Book-Rating'].mean()
# Out:
#                                              Book-Title  \
# 0                             !%@ (A Nutshell handbook)
# 1     'A Hell of a Place to Lose a Cow': An American...
# 2     10,000 dreams interpreted: A dictionary of dreams
# 3                                      101 Famous Poems
# 4                    15 Houseplants Even You Can't Kill
# ...                                                 ...
# 4720                                                Zia
# 4721                                                Zia
# 4722                                Zimmermann Telegram
# 4723  Zoids Chaotic Century (Zoids: Chaotic Century ...
# 4724         Ã?Ã?berleben in der WÃ?ÃÂ¼ste Danakil.
#
#                   Book-Author                       Publisher  Book-Rating
# 0               Donnalyn Frey                        O'Reilly     3.000000
# 1                 Tim Brookes             National Geographic     1.700000
# 2     Gustavus Hindman Miller       Barnes &amp; Nobles Books     6.958333
# 3                 Roy J. Cook  McGraw-Hill/Contemporary Books     3.111111
# 4                   Joe Elder               Berkley Pub Group     0.000000
# ...                       ...                             ...          ...
# 4720             Scott O'Dell               Laurel-Leaf Books     1.859048
# 4721             Scott O'Dell                  Yearling Books     1.859048
# 4722          Barbara Tuchman                Ballantine Books     2.000000
# 4723           Michiro Ueyama                      Viz Comics    10.000000
# 4724    RÃ?ÃÂ¼diger Nehberg                           Piper     3.833333
#
# [4725 rows x 4 columns]

# %% [markdown]
# ### 6) For each book in merged books compute the minimum and maximum of the average ratings over all corresponding books in the books dataset.

# %%
merged_books_w_ratings = pd.merge(merged_books, books_w_ratings, on = ['Book-Title', 'Book-Author', 'Publisher'])
merged_books_w_ratings.head()
# Out:
#                                           Book-Title    Book-Author  \
# 0                          !%@ (A Nutshell handbook)  Donnalyn Frey
# 1                          !%@ (A Nutshell handbook)  Donnalyn Frey
# 2  'A Hell of a Place to Lose a Cow': An American...    Tim Brookes
# 3  'A Hell of a Place to Lose a Cow': An American...    Tim Brookes
# 4  'A Hell of a Place to Lose a Cow': An American...    Tim Brookes
#
#              Publisher  size        ISBN Year-Of-Publication  \
# 0             O'Reilly     2  1565920465                1994
# 1             O'Reilly     2  1565920317                1993
# 2  National Geographic     2  0792276833                2000
# 3  National Geographic     2  0792276833                2000
# 4  National Geographic     2  0792276833                2000
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/1565920465.0...
# 1  http://images.amazon.com/images/P/1565920317.0...
# 2  http://images.amazon.com/images/P/0792276833.0...
# 3  http://images.amazon.com/images/P/0792276833.0...
# 4  http://images.amazon.com/images/P/0792276833.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/1565920465.0...
# 1  http://images.amazon.com/images/P/1565920317.0...
# 2  http://images.amazon.com/images/P/0792276833.0...
# 3  http://images.amazon.com/images/P/0792276833.0...
# 4  http://images.amazon.com/images/P/0792276833.0...
#
#                                          Image-URL-L   User-ID  Book-Rating
# 0  http://images.amazon.com/images/P/1565920465.0...  271245.0          0.0
# 1  http://images.amazon.com/images/P/1565920317.0...   87141.0          6.0
# 2  http://images.amazon.com/images/P/0792276833.0...   79186.0          0.0
# 3  http://images.amazon.com/images/P/0792276833.0...  114216.0          0.0
# 4  http://images.amazon.com/images/P/0792276833.0...  201058.0          0.0

# %%
merged_books_w_ratings.groupby(['Book-Title', 'Book-Author', 'Publisher'], as_index=False)['Book-Rating'].max().head()
# Out:
#                                           Book-Title              Book-Author  \
# 0                          !%@ (A Nutshell handbook)            Donnalyn Frey
# 1  'A Hell of a Place to Lose a Cow': An American...              Tim Brookes
# 2  10,000 dreams interpreted: A dictionary of dreams  Gustavus Hindman Miller
# 3                                   101 Famous Poems              Roy J. Cook
# 4                 15 Houseplants Even You Can't Kill                Joe Elder
#
#                         Publisher  Book-Rating
# 0                        O'Reilly          6.0
# 1             National Geographic          9.0
# 2       Barnes &amp; Nobles Books         10.0
# 3  McGraw-Hill/Contemporary Books         10.0
# 4               Berkley Pub Group          0.0

# %%
merged_books_w_ratings.groupby(['Book-Title', 'Book-Author', 'Publisher'], as_index=False)['Book-Rating'].min().head()
# Out:
#                                           Book-Title              Book-Author  \
# 0                          !%@ (A Nutshell handbook)            Donnalyn Frey
# 1  'A Hell of a Place to Lose a Cow': An American...              Tim Brookes
# 2  10,000 dreams interpreted: A dictionary of dreams  Gustavus Hindman Miller
# 3                                   101 Famous Poems              Roy J. Cook
# 4                 15 Houseplants Even You Can't Kill                Joe Elder
#
#                         Publisher  Book-Rating
# 0                        O'Reilly          0.0
# 1             National Geographic          0.0
# 2       Barnes &amp; Nobles Books          4.0
# 3  McGraw-Hill/Contemporary Books          0.0
# 4               Berkley Pub Group          0.0

# %% [markdown]
# ### 7) For each book in goodbooks, compute the list of its authors. Assuming that the number of reviews with a text (column work_text_reviews_count) is split equally among all authors, find for each authors the total number of reviews with a text. We will call this quantity the shared number of reviews with a text.

# %%
goodbooks.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                       authors  original_publication_year  \
# 0  9.780439e+12               Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPrÃ©                     1997.0
# 2  9.780316e+12               Stephenie Meyer                     2005.0
# 3  9.780061e+12                    Harper Lee                     1960.0
# 4  9.780743e+12           F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %% [markdown]
# - Mia versione:

# %%
#%%timeit
# Ogni elemento della colonna autore è formato dalle stringhe degli autori del libro separati da una virgola
# Converto ogni elemento in una lista degli autori del libro
goodbooks_ = goodbooks.assign(authors=goodbooks['authors'].str.split(','))
goodbooks_.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                          authors  original_publication_year  \
# 0  9.780439e+12                [Suzanne Collins]                     2008.0
# 1  9.780440e+12  [J.K. Rowling,  Mary GrandPrÃ©]                     1997.0
# 2  9.780316e+12                [Stephenie Meyer]                     2005.0
# 3  9.780061e+12                     [Harper Lee]                     1960.0
# 4  9.780743e+12            [F. Scott Fitzgerald]                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %%
# Ottengo una colonna che, per ogni libro, trova il numero delle recensioni testuali divise per il numero di autri
goodbooks_['work_text_reviews_count_per_author'] = goodbooks_['work_text_reviews_count'] / goodbooks_['authors'].str.len()
goodbooks_.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                          authors  original_publication_year  \
# 0  9.780439e+12                [Suzanne Collins]                     2008.0
# 1  9.780440e+12  [J.K. Rowling,  Mary GrandPrÃ©]                     1997.0
# 2  9.780316e+12                [Stephenie Meyer]                     2005.0
# 3  9.780061e+12                     [Harper Lee]                     1960.0
# 4  9.780743e+12            [F. Scott Fitzgerald]                     1925.0
#
#                              original_title  ... work_ratings_count  \
# 0                          The Hunger Games  ...            4942365
# 1  Harry Potter and the Philosopher's Stone  ...            4800065
# 2                                  Twilight  ...            3916824
# 3                     To Kill a Mockingbird  ...            3340896
# 4                          The Great Gatsby  ...            2773745
#
#   work_text_reviews_count  ratings_1  ratings_2  ratings_3  ratings_4  \
# 0                  155254      66715     127936     560092    1481305
# 1                   75867      75504     101676     455024    1156318
# 2                   95009     456191     436802     793319     875073
# 3                   72586      60427     117415     446835    1001952
# 4                   51992      86236     197621     606158     936012
#
#    ratings_5                                          image_url  \
# 0    2706317  https://images.gr-assets.com/books/1447303603m...
# 1    3011543  https://images.gr-assets.com/books/1474154022m...
# 2    1355439  https://images.gr-assets.com/books/1361039443m...
# 3    1714267  https://images.gr-assets.com/books/1361975680m...
# 4     947718  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url  \
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
#    work_text_reviews_count_per_author
# 0                            155254.0
# 1                             37933.5
# 2                             95009.0
# 3                             72586.0
# 4                             51992.0
#
# [5 rows x 24 columns]

# %%
# Splitto ogni riga che presenta n autori in n righe separate, dove a ogni libro è associato un solo oautore
goodbooks_ = goodbooks_.explode('authors')
goodbooks_.head()
goodbooks_.sort_values('original_publication_year')
# Out:
#     book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 78       79               1381          1381   3356006         1703
# 78       79               1381          1381   3356006         1703
# 78       79               1381          1381   3356006         1703
# 78       79               1381          1381   3356006         1703
# 78       79               1381          1381   3356006         1703
# ..      ...                ...           ...       ...          ...
# 68       69           11735983      11735983  15524542          164
# 29       30            8442457      19288043  13306276          196
# 95       96           13536860      13536860  18034963          133
# 5         6           11870085      11870085  16827462          226
# 60       61           22557272      22557272  41107568           14
#
#           isbn        isbn13             authors  original_publication_year  \
# 78   143039954  9.780143e+12               Homer                     -720.0
# 78   143039954  9.780143e+12           E.V. Rieu                     -720.0
# 78   143039954  9.780143e+12   FrÃ©dÃ©ric Mugler                     -720.0
# 78   143039954  9.780143e+12        Bernard Knox                     -720.0
# 78   143039954  9.780143e+12       Robert Fagles                     -720.0
# ..         ...           ...                 ...                        ...
# 68     7442912  9.780007e+12       Veronica Roth                     2012.0
# 29   297859382  9.780298e+12       Gillian Flynn                     2012.0
# 95   345803507  9.780346e+12          E.L. James                     2012.0
# 5    525478817  9.780525e+12          John Green                     2012.0
# 60  1594633665  9.781595e+12       Paula Hawkins                     2015.0
#
#             original_title  ... work_ratings_count work_text_reviews_count  \
# 78       á½Î´ÏÏÏÎµÎ¹Î±  ...             710757                    8101
# 78       á½Î´ÏÏÏÎµÎ¹Î±  ...             710757                    8101
# 78       á½Î´ÏÏÏÎµÎ¹Î±  ...             710757                    8101
# 78       á½Î´ÏÏÏÎµÎ¹Î±  ...             710757                    8101
# 78       á½Î´ÏÏÏÎµÎ¹Î±  ...             710757                    8101
# ..                     ...  ...                ...                     ...
# 68               Insurgent  ...             947338                   55873
# 29               Gone Girl  ...            1626519                  121614
# 95      Fifty Shades Freed  ...             610116                   25287
# 5   The Fault in Our Stars  ...            2478609                  140739
# 60   The Girl on the Train  ...            1226485                   93600
#
#     ratings_1  ratings_2  ratings_3  ratings_4  ratings_5  \
# 78      29703      65629     183082     224120     208223
# 78      29703      65629     183082     224120     208223
# 78      29703      65629     183082     224120     208223
# 78      29703      65629     183082     224120     208223
# 78      29703      65629     183082     224120     208223
# ..        ...        ...        ...        ...        ...
# 68      10641      44620     182131     339977     369969
# 29      38874      80807     280331     616031     610476
# 95      39079      55691     109963     140304     265079
# 5       47994      92723     327550     698471    1311871
# 60      27773      73897     273817     488447     362551
#
#                                             image_url  \
# 78  https://images.gr-assets.com/books/1390173285m...
# 78  https://images.gr-assets.com/books/1390173285m...
# 78  https://images.gr-assets.com/books/1390173285m...
# 78  https://images.gr-assets.com/books/1390173285m...
# 78  https://images.gr-assets.com/books/1390173285m...
# ..                                                ...
# 68  https://images.gr-assets.com/books/1325667729m...
# 29  https://images.gr-assets.com/books/1339602131m...
# 95  https://images.gr-assets.com/books/1336418837m...
# 5   https://images.gr-assets.com/books/1360206420m...
# 60  https://images.gr-assets.com/books/1490903702m...
#
#                                       small_image_url  \
# 78  https://images.gr-assets.com/books/1390173285s...
# 78  https://images.gr-assets.com/books/1390173285s...
# 78  https://images.gr-assets.com/books/1390173285s...
# 78  https://images.gr-assets.com/books/1390173285s...
# 78  https://images.gr-assets.com/books/1390173285s...
# ..                                                ...
# 68  https://images.gr-assets.com/books/1325667729s...
# 29  https://images.gr-assets.com/books/1339602131s...
# 95  https://images.gr-assets.com/books/1336418837s...
# 5   https://images.gr-assets.com/books/1360206420s...
# 60  https://images.gr-assets.com/books/1490903702s...
#
#     work_text_reviews_count_per_author
# 78                              1620.2
# 78                              1620.2
# 78                              1620.2
# 78                              1620.2
# 78                              1620.2
# ..                                 ...
# 68                             55873.0
# 29                            121614.0
# 95                             25287.0
# 5                             140739.0
# 60                             93600.0
#
# [141 rows x 24 columns]

# %%
# Trovo il numero totale di recensioni scritte per autore
columns_ = {"authors": "authors", "work_text_reviews_count_per_author": "shared_number_of_reviews_with_a_text"}
authors_reviews_ = pd.DataFrame(goodbooks_.groupby(['authors'], as_index = False)['work_text_reviews_count_per_author']\
                                .sum().round()).rename(columns = columns_)
authors_reviews_.sort_values('authors')
# Out:
#                       authors  shared_number_of_reviews_with_a_text
# 0              Alan R. Clarke                               27890.0
# 1     B.M. Mooyaart-Doubleday                                6942.0
# 2                Bernard Knox                                1620.0
# 3               CelÃ¢l Ãster                               15173.0
# 4               David J. Skal                                5754.0
# ..                        ...                                   ...
# 105             Veronica Roth                              156896.0
# 106           William Golding                               26886.0
# 107           William Goldman                               15630.0
# 108       William Shakespeare                                7389.0
# 109               Yann Martel                               42962.0
#
# [110 rows x 2 columns]

# %%
# possibile idea, creo una tabella ponte tra book_id e autore (test, non so a cosa possa servire)
# Per renderla più efficace dovrei assegnare ad ogni autore un id
gb_books_authors = goodbooks_[['book_id', 'authors']]
gb_books_authors.head()
# Out:
#    book_id          authors
# 0        1  Suzanne Collins
# 1        2     J.K. Rowling
# 1        2   Mary GrandPrÃ©
# 2        3  Stephenie Meyer
# 3        4       Harper Lee

# %% [markdown]
# * Soluzione di gianluca

# %%
gb_authors = {}

def gb_diz(authors, count):
    for i in range(len(authors)):
        occ = authors[i].split(',')
        for elem in occ:
            if elem in gb_authors:
                gb_authors[elem] += count[i]/len(occ)
            else:
                gb_authors[elem] = count[i]/len(occ)

# %%
authors = list(goodbooks['authors'])
work_text_reviews_count = list(goodbooks['work_text_reviews_count'])

# %%
gb_diz(authors, work_text_reviews_count)

# %%
gb_authors
# Out:
# {'Suzanne Collins': 340066.0,
#  'J.K. Rowling': 136668.0,
#  ' Mary GrandPrÃ©': 136668.0,
#  'Stephenie Meyer': 258573.0,
#  'Harper Lee': 72586.0,
#  'F. Scott Fitzgerald': 51992.0,
#  'John Green': 230584.0,
#  'J.R.R. Tolkien': 52986.0,
#  'J.D. Salinger': 44920.0,
#  'Dan Brown': 66672.0,
#  'Jane Austen': 52994.0,
#  'Khaled Hosseini': 103375.0,
#  'Veronica Roth': 156896.0,
#  'George Orwell': 50644.666666666664,
#  ' Erich Fromm': 15172.666666666666,
#  ' CelÃ¢l Ã\x9cster': 15172.666666666666,
#  'Anne Frank': 6941.666666666667,
#  ' Eleanor Roosevelt': 6941.666666666667,
#  ' B.M. Mooyaart-Doubleday': 6941.666666666667,
#  'Stieg Larsson': 46983.0,
#  ' Reg Keeland': 46983.0,
#  ' Rufus Beck': 12033.0,
#  'Alice Sebold': 36642.0,
#  'William Golding': 26886.0,
#  'William Shakespeare': 7389.0,
#  ' Robert           Jackson': 7389.0,
#  'Gillian Flynn': 121614.0,
#  'Kathryn Stockett': 78204.0,
#  'John Steinbeck': 24642.0,
#  'Arthur Golden': 25605.0,
#  'E.L. James': 128776.0,
#  'Paulo Coelho': 27890.5,
#  ' Alan R. Clarke': 27890.5,
#  'Lois Lowry': 54084.0,
#  'C.S. Lewis': 15186.0,
#  'Audrey Niffenegger': 43382.0,
#  'George R.R. Martin': 46205.0,
#  'Elizabeth Gilbert': 49714.0,
#  'Rick Riordan': 46006.0,
#  'Louisa May Alcott': 17090.0,
#  'Charlotte BrontÃ«': 15606.0,
#  ' Michael Mason': 15606.0,
#  'Nicholas Sparks': 17279.0,
#  'Yann Martel': 42962.0,
#  'Sara Gruen': 55732.0,
#  'Markus Zusak': 93611.0,
#  'Ray Bradbury': 30694.0,
#  'Shel Silverstein': 23602.0,
#  'Cassandra Clare': 51589.0,
#  'Christopher Paolini': 18280.0,
#  'Douglas Adams': 20345.0,
#  'Aldous Huxley': 20095.0,
#  'Sue Monk Kidd': 26522.0,
#  'Mark Twain': 4149.333333333333,
#  ' John Seelye': 4149.333333333333,
#  ' Guy Cardwell': 4149.333333333333,
#  'E.B. White': 4348.0,
#  ' Garth Williams': 4348.0,
#  ' Rosemary Wells': 4348.0,
#  'Mark Haddon': 35796.0,
#  'Paula Hawkins': 93600.0,
#  'Philip Pullman': 14915.0,
#  'Emily BrontÃ«': 13078.5,
#  ' Richard J. Dunn': 13078.5,
#  'Jodi Picoult': 30719.0,
#  'Kurt Vonnegut Jr.': 19646.0,
#  'Margaret Mitchell': 16050.0,
#  'Stephen Chbosky': 47116.0,
#  'Orson Scott Card': 38054.0,
#  'Mary Wollstonecraft Shelley': 6664.333333333333,
#  ' Percy Bysshe Shelley': 6664.333333333333,
#  ' Maurice Hindle': 6664.333333333333,
#  'Stephen King': 14936.0,
#  'Helen Fielding': 8157.0,
#  ' Tony Tanner': 3842.0,
#  ' Ros Ballaster': 3842.0,
#  'Louis Sachar': 7916.0,
#  ' Louis Sachar': 7916.0,
#  'Lauren Weisberger': 8024.0,
#  'Homer': 1620.2,
#  ' Robert Fagles': 1620.2,
#  ' E.V. Rieu': 1620.2,
#  ' FrÃ©dÃ©ric Mugler': 1620.2,
#  ' Bernard Knox': 1620.2,
#  'Antoine de Saint-ExupÃ©ry': 6134.25,
#  ' Richard Howard': 6134.25,
#  ' Dom Marcos Barbosa': 6134.25,
#  ' Melina Karakosta': 6134.25,
#  'Jeannette Walls': 40777.0,
#  'Jon Krakauer': 17299.0,
#  'Charles Dickens': 4364.333333333333,
#  ' Richard Maxwell': 4364.333333333333,
#  ' Hablot Knight Browne': 4364.333333333333,
#  'Michael Crichton': 8143.0,
#  'John Grisham': 4239.0,
#  'Elie Wiesel': 11000.5,
#  ' Marion Wiesel': 11000.5,
#  'William Goldman': 15630.0,
#  'S.E. Hinton': 22662.0,
#  'James Dashner': 48942.0,
#  'Steven D. Levitt': 6834.0,
#  ' Stephen J. Dubner': 6834.0,
#  'Frances Hodgson Burnett': 13054.0,
#  'Gabriel GarcÃ\xada MÃ¡rquez': 10835.5,
#  ' Gregory Rabassa': 10835.5,
#  'Oscar Wilde': 9823.5,
#  ' Jeffrey Eugenides': 9823.5,
#  'Bram Stoker': 5754.333333333333,
#  ' Nina Auerbach': 5754.333333333333,
#  ' David J. Skal': 5754.333333333333}

# %%
len(gb_authors)
# Out:
# 110

# %%
authors_reviews = pd.DataFrame.from_dict(gb_authors, orient = 'index', columns = ['shared number of reviews with a text'])
authors_reviews
# Out:
#                     shared number of reviews with a text
# Suzanne Collins                            340066.000000
# J.K. Rowling                               136668.000000
#  Mary GrandPrÃ©                            136668.000000
# Stephenie Meyer                            258573.000000
# Harper Lee                                  72586.000000
# ...                                                  ...
# Oscar Wilde                                  9823.500000
#  Jeffrey Eugenides                           9823.500000
# Bram Stoker                                  5754.333333
#  Nina Auerbach                               5754.333333
#  David J. Skal                               5754.333333
#
# [110 rows x 1 columns]

# %% [markdown]
# ### 8) For each year of publication, determine the author that has the largest value of the shared number of reviews with a text.

# %% [markdown]
# Possibile significato della domanda:
# 1) Per ogni anno, trovare l'autore che, per un libro scritto in quell'anno, ha ottenuto il massimo numero di recensioni scritte per quel libro (crea problema perchè se un libro ha coautori questi saranno entrambi valore max)
# 2) Per ogni anno, trovare l'autore che, sommando il numero delle recensioni per tutti i libri scritti in quell'anno ha il numero massimo
# 3) Per ogni anno, trovare l'autore che, avendo publicato un libro in quell'anno, ha il numero TOTALE massimo di recensioni (contando libri scritti in tutta la sua carriera contenuti nel dataset)

# %%
goodbooks_.columns
# Out:
# Index(['book_id', 'goodreads_book_id', 'best_book_id', 'work_id',
#        'books_count', 'isbn', 'isbn13', 'authors', 'original_publication_year',
#        'original_title', 'title', 'language_code', 'average_rating',
#        'ratings_count', 'work_ratings_count', 'work_text_reviews_count',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'image_url', 'small_image_url', 'work_text_reviews_count_per_author'],
#       dtype='object')

# %%
import numpy as np
np.sort(goodbooks_['original_publication_year'].unique())
# Il valore negativo è relativo all'odissea
# Out:
# array([-720., 1595., 1811., 1813., 1818., 1847., 1859., 1868., 1884.,
#        1891., 1897., 1911., 1925., 1932., 1936., 1937., 1945., 1946.,
#        1947., 1949., 1950., 1951., 1952., 1953., 1954., 1958., 1960.,
#        1964., 1967., 1969., 1973., 1974., 1977., 1979., 1985., 1988.,
#        1989., 1990., 1993., 1995., 1996., 1997., 1998., 1999., 2000.,
#        2001., 2002., 2003., 2004., 2005., 2006., 2007., 2008., 2009.,
#        2010., 2011., 2012., 2015.])

# %% [markdown]
# Ipotizzo che la domanda giusta sia la 2)

# %%
# goodbooks_.groupby(['original_publication_year'], as_index=False)['work_text_reviews_count_per_author'].max()
# Devo scrivere per forza un sum() prima del max() per includere gli autori che hanno scritto più di un libro nello stesso anno
colonne = {'original_publication_year':'original_publication_year', 'authors':'authors', \
           'work_text_reviews_count_per_author':'shared_number_of_reviews_with_a_text'}
gb_year_author_shared = goodbooks_.groupby(['original_publication_year', 'authors'], as_index=False)\
            ['work_text_reviews_count_per_author'].sum().round().rename(columns = colonne)
gb_year_author_shared.head(20)
# Out:
#     original_publication_year                      authors  \
# 0                      -720.0                 Bernard Knox
# 1                      -720.0                    E.V. Rieu
# 2                      -720.0            FrÃ©dÃ©ric Mugler
# 3                      -720.0                Robert Fagles
# 4                      -720.0                        Homer
# 5                      1595.0     Robert           Jackson
# 6                      1595.0          William Shakespeare
# 7                      1811.0                Ros Ballaster
# 8                      1811.0                  Tony Tanner
# 9                      1811.0                  Jane Austen
# 10                     1813.0                  Jane Austen
# 11                     1818.0               Maurice Hindle
# 12                     1818.0         Percy Bysshe Shelley
# 13                     1818.0  Mary Wollstonecraft Shelley
# 14                     1847.0                Michael Mason
# 15                     1847.0              Richard J. Dunn
# 16                     1847.0            Charlotte BrontÃ«
# 17                     1847.0                Emily BrontÃ«
# 18                     1859.0         Hablot Knight Browne
# 19                     1859.0              Richard Maxwell
#
#     shared_number_of_reviews_with_a_text
# 0                                 1620.0
# 1                                 1620.0
# 2                                 1620.0
# 3                                 1620.0
# 4                                 1620.0
# 5                                 7389.0
# 6                                 7389.0
# 7                                 3842.0
# 8                                 3842.0
# 9                                 3842.0
# 10                               49152.0
# 11                                6664.0
# 12                                6664.0
# 13                                6664.0
# 14                               15606.0
# 15                               13078.0
# 16                               15606.0
# 17                               13078.0
# 18                                4364.0
# 19                                4364.0

# %%
# Ora seleziono, per ogni anno, gli autori con shared massimo
best_author_of_the_year = gb_year_author_shared.iloc[gb_year_author_shared.groupby(['original_publication_year'])\
                                   ['shared_number_of_reviews_with_a_text'].idxmax()]
best_author_of_the_year.head(30)
# I valori si discostano da quelli delle soluzioni perchè ho deciso di effettuare il sum per un certo autore in uno specifico anno
# Se mi limitassi a scegliere l'autore, per ogni anno, che per un certo libro presenta il massimo numero di recensioni scritte
# allora coincidono (dovrei seplicemente saltare il passaggio del sum e fare direttamente idxmax)
# Oltretutto ci sarebbero sicuramente dei duplicati per quei libri publicati da più autori
# Out:
#     original_publication_year                    authors  \
# 0                      -720.0               Bernard Knox
# 5                      1595.0   Robert           Jackson
# 7                      1811.0              Ros Ballaster
# 10                     1813.0                Jane Austen
# 11                     1818.0             Maurice Hindle
# ..                        ...                        ...
# 55                     1958.0              Marion Wiesel
# 57                     1960.0                 Harper Lee
# 58                     1964.0           Shel Silverstein
# 61                     1967.0                S.E. Hinton
# 62                     1969.0          Kurt Vonnegut Jr.
#
#     shared_number_of_reviews_with_a_text
# 0                                 1620.0
# 5                                 7389.0
# 7                                 3842.0
# 10                               49152.0
# 11                                6664.0
# ..                                   ...
# 55                               11000.0
# 57                               72586.0
# 58                               14368.0
# 61                               22662.0
# 62                               19646.0
#
# [30 rows x 3 columns]

# %% [markdown]
# * Soluzione alternativa 3) (considero lo shared generale)

# %%
goodbooks_reviews = pd.merge(goodbooks_, authors_reviews_, on = 'authors')
goodbooks_reviews
# Out:
#      book_id  goodreads_book_id  best_book_id  work_id  books_count  \
# 0          1            2767052       2767052  2792775          272
# 1         17            6148028       6148028  6171458          201
# 2         20            7260188       7260188  8812783          239
# 3          2                  3             3  4640799          491
# 4         18                  5             5  2402163          376
# ..       ...                ...           ...      ...          ...
# 136       95               5297          5297  1858012         2303
# 137       95               5297          5297  1858012         2303
# 138       97              17245         17245  3165724         2207
# 139       97              17245         17245  3165724         2207
# 140       97              17245         17245  3165724         2207
#
#            isbn        isbn13             authors  original_publication_year  \
# 0     439023483  9.780439e+12     Suzanne Collins                     2008.0
# 1     439023491  9.780439e+12     Suzanne Collins                     2009.0
# 2     439023513  9.780439e+12     Suzanne Collins                     2010.0
# 3     439554934  9.780440e+12        J.K. Rowling                     1997.0
# 4    043965548X  9.780440e+12        J.K. Rowling                     1999.0
# ..          ...           ...                 ...                        ...
# 136   375751513  9.780376e+12         Oscar Wilde                     1891.0
# 137   375751513  9.780376e+12   Jeffrey Eugenides                     1891.0
# 138   393970124  9.780394e+12         Bram Stoker                     1897.0
# 139   393970124  9.780394e+12       Nina Auerbach                     1897.0
# 140   393970124  9.780394e+12       David J. Skal                     1897.0
#
#                                original_title  ... work_text_reviews_count  \
# 0                            The Hunger Games  ...                  155254
# 1                               Catching Fire  ...                   88538
# 2                                  Mockingjay  ...                   96274
# 3    Harry Potter and the Philosopher's Stone  ...                   75867
# 4    Harry Potter and the Prisoner of Azkaban  ...                   36099
# ..                                        ...  ...                     ...
# 136                The Picture of Dorian Gray  ...                   19647
# 137                The Picture of Dorian Gray  ...                   19647
# 138                                   Dracula  ...                   17263
# 139                                   Dracula  ...                   17263
# 140                                   Dracula  ...                   17263
#
#     ratings_1  ratings_2  ratings_3  ratings_4  ratings_5  \
# 0       66715     127936     560092    1481305    2706317
# 1       10492      48030     262010     687238     980309
# 2       30144     110498     373060     618271     738775
# 3       75504     101676     455024    1156318    3011543
# 4        6716      20413     166129     509447    1266670
# ..        ...        ...        ...        ...        ...
# 136      9825      30735     129420     246892     257679
# 137      9825      30735     129420     246892     257679
# 138     11756      36719     151396     246043     243825
# 139     11756      36719     151396     246043     243825
# 140     11756      36719     151396     246043     243825
#
#                                              image_url  \
# 0    https://images.gr-assets.com/books/1447303603m...
# 1    https://images.gr-assets.com/books/1358273780m...
# 2    https://images.gr-assets.com/books/1358275419m...
# 3    https://images.gr-assets.com/books/1474154022m...
# 4    https://images.gr-assets.com/books/1499277281m...
# ..                                                 ...
# 136  https://images.gr-assets.com/books/1424596966m...
# 137  https://images.gr-assets.com/books/1424596966m...
# 138  https://images.gr-assets.com/books/1387151694m...
# 139  https://images.gr-assets.com/books/1387151694m...
# 140  https://images.gr-assets.com/books/1387151694m...
#
#                                        small_image_url  \
# 0    https://images.gr-assets.com/books/1447303603s...
# 1    https://images.gr-assets.com/books/1358273780s...
# 2    https://images.gr-assets.com/books/1358275419s...
# 3    https://images.gr-assets.com/books/1474154022s...
# 4    https://images.gr-assets.com/books/1499277281s...
# ..                                                 ...
# 136  https://images.gr-assets.com/books/1424596966s...
# 137  https://images.gr-assets.com/books/1424596966s...
# 138  https://images.gr-assets.com/books/1387151694s...
# 139  https://images.gr-assets.com/books/1387151694s...
# 140  https://images.gr-assets.com/books/1387151694s...
#
#      work_text_reviews_count_per_author  shared_number_of_reviews_with_a_text
# 0                         155254.000000                              340066.0
# 1                          88538.000000                              340066.0
# 2                          96274.000000                              340066.0
# 3                          37933.500000                              136668.0
# 4                          12033.000000                              136668.0
# ..                                  ...                                   ...
# 136                         9823.500000                                9824.0
# 137                         9823.500000                                9824.0
# 138                         5754.333333                                5754.0
# 139                         5754.333333                                5754.0
# 140                         5754.333333                                5754.0
#
# [141 rows x 25 columns]

# %%
goodbooks_reviews.iloc[goodbooks_reviews.groupby(['original_publication_year'])['shared_number_of_reviews_with_a_text']\
                       .idxmax()][['original_publication_year', 'authors','shared_number_of_reviews_with_a_text']]
# Out:
#      original_publication_year                      authors  \
# 110                     -720.0                        Homer
# 52                      1595.0          William Shakespeare
# 33                      1811.0                  Jane Austen
# 32                      1813.0                  Jane Austen
# 100                     1818.0  Mary Wollstonecraft Shelley
# ..                         ...                          ...
# 1                       2009.0              Suzanne Collins
# 2                       2010.0              Suzanne Collins
# 36                      2011.0                Veronica Roth
# 24                      2012.0                   John Green
# 91                      2015.0                Paula Hawkins
#
#      shared_number_of_reviews_with_a_text
# 110                                1620.0
# 52                                 7389.0
# 33                                52994.0
# 32                                52994.0
# 100                                6664.0
# ..                                    ...
# 1                                340066.0
# 2                                340066.0
# 36                               156896.0
# 24                               230584.0
# 91                                93600.0
#
# [58 rows x 3 columns]

# %% [markdown]
# ### 9) Assuming that there are no errors in the ISBN fields, find the books in both datasets, and compute the difference of average rating according to the ratings and the goodratings datasets

# %%
both = pd.merge(goodbooks[['book_id', 'isbn', 'authors', 'title', 'average_rating']], books_avg[['ISBN', 'Book-Rating']], 
                left_on = 'isbn', right_on = 'ISBN')
both
# Out:
#    book_id        isbn                                   authors  \
# 0       11  1594480001                           Khaled Hosseini
# 1       18  043965548X  J.K. Rowling, Mary GrandPrÃ©, Rufus Beck
# 2       60  1400032717                               Mark Haddon
# 3       75  014028009X                            Helen Fielding
# 4       90  014038572X                               S.E. Hinton
#
#                                                title  average_rating  \
# 0                                    The Kite Runner            4.26
# 1  Harry Potter and the Prisoner of Azkaban (Harr...            4.53
# 2  The Curious Incident of the Dog in the Night-Time            3.85
# 3          Bridget Jones's Diary (Bridget Jones, #1)            3.75
# 4                                      The Outsiders            4.06
#
#          ISBN  Book-Rating
# 0  1594480001     2.400000
# 1  043965548X     3.533333
# 2  1400032717     4.813187
# 3  014028009X     3.751852
# 4  014038572X     4.460674

# %%
both['avg_difference'] = both['average_rating']-both['Book-Rating']
both
# Out:
#    book_id        isbn                                   authors  \
# 0       11  1594480001                           Khaled Hosseini
# 1       18  043965548X  J.K. Rowling, Mary GrandPrÃ©, Rufus Beck
# 2       60  1400032717                               Mark Haddon
# 3       75  014028009X                            Helen Fielding
# 4       90  014038572X                               S.E. Hinton
#
#                                                title  average_rating  \
# 0                                    The Kite Runner            4.26
# 1  Harry Potter and the Prisoner of Azkaban (Harr...            4.53
# 2  The Curious Incident of the Dog in the Night-Time            3.85
# 3          Bridget Jones's Diary (Bridget Jones, #1)            3.75
# 4                                      The Outsiders            4.06
#
#          ISBN  Book-Rating  avg_difference
# 0  1594480001     2.400000        1.860000
# 1  043965548X     3.533333        0.996667
# 2  1400032717     4.813187       -0.963187
# 3  014028009X     3.751852       -0.001852
# 4  014038572X     4.460674       -0.400674

# %% [markdown]
# ### 10) Split the users dataset according to the age. One dataset contains the users with unknown age, one with age 0-14, one with age 15-24, one with age 25-34, and so on.

# %%
users.head()
# Out:
#    User-ID   Age         City            Region          Country
# 0        1   NaN          nyc          new york              usa
# 1        2  18.0     stockton        california              usa
# 2        3   NaN       moscow   yukon territory           russia
# 3        4  17.0        porto          v.n.gaia         portugal
# 4        5   NaN  farnborough             hants   united kingdom

# %%
users_nan = users[users['Age'].isnull()]
users_nan
# Out:
#         User-ID  Age         City            Region          Country
# 0             1  NaN          nyc          new york              usa
# 2             3  NaN       moscow   yukon territory           russia
# 4             5  NaN  farnborough             hants   united kingdom
# 6             7  NaN   washington                dc              usa
# 7             8  NaN      timmins           ontario           canada
# ...         ...  ...          ...               ...              ...
# 278849   278850  NaN     sergnano         lombardia            italy
# 278853   278854  NaN     portland            oregon              usa
# 278855   278856  NaN     brampton           ontario           canada
# 278856   278857  NaN    knoxville         tennessee              usa
# 278857   278858  NaN       dublin               n/a          ireland
#
# [110762 rows x 5 columns]

# %%
users_temp = users[users['Age'].notnull()]
users_temp
# Out:
#         User-ID   Age          City       Region          Country
# 1             2  18.0      stockton   california              usa
# 3             4  17.0         porto     v.n.gaia         portugal
# 5             6  61.0  santa monica   california              usa
# 9            10  26.0      albacete    wisconsin            spain
# 10           11  14.0     melbourne     victoria        australia
# ...         ...   ...           ...          ...              ...
# 278848   278849  23.0    georgetown      ontario           canada
# 278850   278851  33.0        dallas        texas              usa
# 278851   278852  32.0      brisbane   queensland        australia
# 278852   278853  17.0     stranraer          n/a   united kingdom
# 278854   278855  50.0        tacoma   washington   united kingdom
#
# [168096 rows x 5 columns]

# %%
users_temp['Age_group'] = pd.cut(users_temp['Age'], bins = [0, 15, 25, 35, 45, 55, 65, 75, 85, 95, 1000], right = False,
                                labels = ['<15', '15-24', '25-34', '35-44', '45-54', '55-64', '65-74', '75-84', '85-94', '>95'])
users_temp
# Out:
# <ipython-input-42-64c3c3f37d7c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_temp['Age_group'] = pd.cut(users_temp['Age'], bins = [0, 15, 25, 35, 45, 55, 65, 75, 85, 95, 1000], right = False,
#         User-ID   Age          City       Region          Country Age_group
# 1             2  18.0      stockton   california              usa     15-24
# 3             4  17.0         porto     v.n.gaia         portugal     15-24
# 5             6  61.0  santa monica   california              usa     55-64
# 9            10  26.0      albacete    wisconsin            spain     25-34
# 10           11  14.0     melbourne     victoria        australia       <15
# ...         ...   ...           ...          ...              ...       ...
# 278848   278849  23.0    georgetown      ontario           canada     15-24
# 278850   278851  33.0        dallas        texas              usa     25-34
# 278851   278852  32.0      brisbane   queensland        australia     25-34
# 278852   278853  17.0     stranraer          n/a   united kingdom     15-24
# 278854   278855  50.0        tacoma   washington   united kingdom     45-54
#
# [168096 rows x 6 columns]

# %%
grouped = users_temp.groupby(users_temp.Age_group)

x = list(grouped.groups)
df = {}

for elem in x:
    df[elem] = grouped.get_group(elem)
    
df['>95']
# Out:
#         User-ID    Age                   City                Region  \
# 1288       1289  103.0               san jose            california
# 1322       1323  104.0                 milano             lombardia
# 1578       1579  231.0                  akure          ondo/nigeria
# 3084       3085  104.0                zÃ¼rich           switzerland
# 3210       3211  119.0  le mesnil saint denis              yvelines
# ...         ...    ...                    ...                   ...
# 276352   276353  104.0              hillsdale              new york
# 277107   277108  104.0                 quinto                ticino
# 277503   277504  103.0              san diego            california
# 277558   277559   98.0            lake george              new york
# 278301   278302  104.0            dÃ¼sseldorf   nordrhein-westfalen
#
#              Country Age_group
# 1288             usa       >95
# 1322           italy       >95
# 1578         nigeria       >95
# 3084     switzerland       >95
# 3210          france       >95
# ...              ...       ...
# 276352           usa       >95
# 277107   switzerland       >95
# 277503           usa       >95
# 277558           usa       >95
# 278301       germany       >95
#
# [386 rows x 6 columns]

# %% [markdown]
# ### 11) Find the books that appear only in the goodbooks datasets.

# %%
only_goodbooks = pd.merge(goodbooks, books['ISBN'], left_on = 'isbn', right_on = 'ISBN', how = 'left')
only_goodbooks[only_goodbooks['ISBN'].isnull()]
# Out:
#     book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0         1            2767052       2767052   2792775          272
# 1         2                  3             3   4640799          491
# 2         3              41865         41865   3212258          226
# 3         4               2657          2657   3275794          487
# 4         5               4671          4671    245494         1356
# ..      ...                ...           ...       ...          ...
# 94       95               5297          5297   1858012         2303
# 95       96           13536860      13536860  18034963          133
# 96       97              17245         17245   3165724         2207
# 97       98            5060378       5060378   6976108          209
# 98       99           11857408      11857408  16813814          147
#
#           isbn        isbn13                                    authors  \
# 0    439023483  9.780439e+12                            Suzanne Collins
# 1    439554934  9.780440e+12               J.K. Rowling, Mary GrandPrÃ©
# 2    316015849  9.780316e+12                            Stephenie Meyer
# 3     61120081  9.780061e+12                                 Harper Lee
# 4    743273567  9.780743e+12                        F. Scott Fitzgerald
# ..         ...           ...                                        ...
# 94   375751513  9.780376e+12             Oscar Wilde, Jeffrey Eugenides
# 95   345803507  9.780346e+12                                 E.L. James
# 96   393970124  9.780394e+12  Bram Stoker, Nina Auerbach, David J. Skal
# 97   307269981  9.780307e+12                 Stieg Larsson, Reg Keeland
# 98  1612130585  9.781612e+12                                 E.L. James
#
#     original_publication_year                            original_title  ...  \
# 0                      2008.0                          The Hunger Games  ...
# 1                      1997.0  Harry Potter and the Philosopher's Stone  ...
# 2                      2005.0                                  Twilight  ...
# 3                      1960.0                     To Kill a Mockingbird  ...
# 4                      1925.0                          The Great Gatsby  ...
# ..                        ...                                       ...  ...
# 94                     1891.0                The Picture of Dorian Gray  ...
# 95                     2012.0                        Fifty Shades Freed  ...
# 96                     1897.0                                   Dracula  ...
# 97                     2006.0               Flickan som lekte med elden  ...
# 98                     2011.0                       Fifty Shades Darker  ...
#
#    work_ratings_count work_text_reviews_count  ratings_1  ratings_2  \
# 0             4942365                  155254      66715     127936
# 1             4800065                   75867      75504     101676
# 2             3916824                   95009     456191     436802
# 3             3340896                   72586      60427     117415
# 4             2773745                   51992      86236     197621
# ..                ...                     ...        ...        ...
# 94             674551                   19647       9825      30735
# 95             610116                   25287      39079      55691
# 96             689739                   17263      11756      36719
# 97             649253                   31423       4623      15781
# 98             623340                   28052      37245      58935
#
#     ratings_3  ratings_4  ratings_5  \
# 0      560092    1481305    2706317
# 1      455024    1156318    3011543
# 2      793319     875073    1355439
# 3      446835    1001952    1714267
# 4      606158     936012     947718
# ..        ...        ...        ...
# 94     129420     246892     257679
# 95     109963     140304     265079
# 96     151396     246043     243825
# 97      91021     258236     279592
# 98     114203     150906     262051
#
#                                             image_url  \
# 0   https://images.gr-assets.com/books/1447303603m...
# 1   https://images.gr-assets.com/books/1474154022m...
# 2   https://images.gr-assets.com/books/1361039443m...
# 3   https://images.gr-assets.com/books/1361975680m...
# 4   https://images.gr-assets.com/books/1490528560m...
# ..                                                ...
# 94  https://images.gr-assets.com/books/1424596966m...
# 95  https://images.gr-assets.com/books/1336418837m...
# 96  https://images.gr-assets.com/books/1387151694m...
# 97  https://images.gr-assets.com/books/1351778881m...
# 98  https://images.gr-assets.com/books/1358266080m...
#
#                                       small_image_url  ISBN
# 0   https://images.gr-assets.com/books/1447303603s...   NaN
# 1   https://images.gr-assets.com/books/1474154022s...   NaN
# 2   https://images.gr-assets.com/books/1361039443s...   NaN
# 3   https://images.gr-assets.com/books/1361975680s...   NaN
# 4   https://images.gr-assets.com/books/1490528560s...   NaN
# ..                                                ...   ...
# 94  https://images.gr-assets.com/books/1424596966s...   NaN
# 95  https://images.gr-assets.com/books/1336418837s...   NaN
# 96  https://images.gr-assets.com/books/1387151694s...   NaN
# 97  https://images.gr-assets.com/books/1351778881s...   NaN
# 98  https://images.gr-assets.com/books/1358266080s...   NaN
#
# [94 rows x 24 columns]

# %% [markdown]
# ### 12) Assuming that each pair (author, title) identifies a book, for each book find the number of times it appears in the books dataset. Which books appear the most times?

# %%
pairs = books.groupby(['Book-Title', 'Book-Author'], as_index = False).size()
pairs.loc[pairs['size'].idxmax()]
# Out:
# Book-Title          Little Women
# Book-Author    Louisa May Alcott
# size                          21
# Name: 113850, dtype: object

# %% [markdown]
# ### 13) Find the author with the highest average ratio according to the goodbooks datasets.

# %%
# Per come l'ho intesa io, dobbiamo andare a fare esattamente come nel punto 7), replicando ogni riga un numero di volte pari
# al numero di autori di quel libro. Quindi, possiamo usare il dataframe goodbooks_ che hai già costruito in quel punto. A 
# questo punto, credo che la richiesta sia quella di andare a fare una groupby sul nome dell'autore per poi calcolare la media
# del rating, che nel database goodbooks di partenza è già presente nella colonna 'average_rating'.
goodbooks_.columns
# Out:
# Index(['book_id', 'goodreads_book_id', 'best_book_id', 'work_id',
#        'books_count', 'isbn', 'isbn13', 'authors', 'original_publication_year',
#        'original_title', 'title', 'language_code', 'average_rating',
#        'ratings_count', 'work_ratings_count', 'work_text_reviews_count',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'image_url', 'small_image_url', 'work_text_reviews_count_per_author'],
#       dtype='object')

# %%
goodbooks_avg_rating = goodbooks_[['authors', 'average_rating']]
goodbooks_avg_rating
# Out:
#             authors  average_rating
# 0   Suzanne Collins            4.34
# 1      J.K. Rowling            4.44
# 1    Mary GrandPrÃ©            4.44
# 2   Stephenie Meyer            3.57
# 3        Harper Lee            4.25
# ..              ...             ...
# 96    Nina Auerbach            3.98
# 96    David J. Skal            3.98
# 97    Stieg Larsson            4.22
# 97      Reg Keeland            4.22
# 98       E.L. James            3.87
#
# [141 rows x 2 columns]

# %%
goodbooks_avg_rating_per_author = goodbooks_avg_rating.groupby('authors', as_index = False).mean()
goodbooks_avg_rating_per_author
# Out:
#                       authors  average_rating
# 0              Alan R. Clarke           3.820
# 1     B.M. Mooyaart-Doubleday           4.100
# 2                Bernard Knox           3.730
# 3               CelÃ¢l Ãster           4.140
# 4               David J. Skal           3.980
# ..                        ...             ...
# 105             Veronica Roth           4.155
# 106           William Golding           3.640
# 107           William Goldman           4.250
# 108       William Shakespeare           3.730
# 109               Yann Martel           3.880
#
# [110 rows x 2 columns]

# %%
goodbooks_avg_rating_per_author.iloc[goodbooks_avg_rating_per_author['average_rating'].idxmax()]
# Out:
# authors            Rufus Beck
# average_rating           4.53
# Name: 32, dtype: object
